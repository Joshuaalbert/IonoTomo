# %%
import astropy.coordinates as ac
import astropy.units as au
import time
import numpy as np

if __name__=='__main__':
    x = np.linspace(0,np.pi/2.,10)
    X,Y = np.meshgrid(x,x)
    print ("testing vectorized")
    t1 = time.time()
    loc_vec = ac.SkyCoord(ra=X*au.rad,dec=Y*au.rad)
    print("time: {}".format(time.time()-t1))
    print("testing non vectorized")
    loc_seq = []
    t1 = time.time()
    i = 0
    while i < len(x):
        row = []
        j = 0
        while j < len(x):
            row.append(ac.SkyCoord(ra=x[i]*au.rad,dec=x[j]*au.rad))
            j += 1
        loc_seq.append(row)
        i += 1
    print("time: {}".format(time.time()-t1))
    #print loc_vec,loc_seq
    print loc_vec.supergalactic
# Out:
# testing vectorized
# time: 0.00389003753662
# testing non vectorized
# time: 0.202857017517
# <SkyCoord (Supergalactic): (sgl, sgb) in deg
#     [[(292.65873159, 13.23084202), (295.43256196, 3.61367985),
#       (298.14765091, -6.01174906), (300.96137472, -15.62329284),
#       (304.0540974, -25.19544975), (307.67720572, -34.69226997),
#       (312.24066711, -44.0539875), (318.50537769, -53.16599462),
#       (328.05050645, -61.77492189), (344.33493621, -69.23552779)],
#      [(302.64153423, 15.80791191), (305.11221834, 6.26266399),
#       (307.78159151, -3.21747059), (310.79334301, -12.60360142),
#       (314.33769012, -21.85288269), (318.69305662, -30.89766739),
#       (324.29488404, -39.62475399), (331.84936089, -47.83381195),
#       (342.4798548, -55.15446338), (357.66446537, -60.90620823)],
#      [(312.85722259, 17.91912203), (314.88685764, 8.73298266),
#       (317.36221233, -0.33312736), (320.38408033, -9.23404844),
#       (324.11141161, -17.9045393), (328.78168128, -26.24697946),
#       (334.73900557, -34.11113134), (342.45603669, -41.26213373),
#       (352.49457034, -47.33745727), (5.26271473, -51.81821109)],
#      [(323.28613339, 19.48662096), (324.78458023, 10.95043796),
#       (326.93723872, 2.56050291), (329.78714178, -5.61567835),
#       (333.43617886, -13.49132874), (338.0437898, -20.94914756),
#       (343.8230722, -27.82698947), (351.01741078, -33.90174891),
#       (359.82756701, -38.87892328), (10.25809606, -42.40742445)],
#      [(333.87833258, 20.44838392), (334.82006768, 12.84521288),
#       (336.55491052, 5.38256695), (339.07214386, -1.84922168),
#       (342.41084327, -8.74723829), (346.64640851, -15.18718758),
#       (351.87292068, -21.01566058), (358.17240315, -26.04572527),
#       (5.56321113, -30.06115268), (13.93112748, -32.83703936)],
#      [(344.55846605, 20.76432767), (344.99176541, 14.3545247),
#       (346.25949477, 8.05283593), (348.31767964, 1.96545368),
#       (351.15524436, -3.7976254), (354.77991927, -9.1168013),
#       (359.2012449, -13.85976796), (4.40857907, -17.88242268),
#       (10.34463732, -21.03578852), (16.88063146, -23.18048751)],
#      [(355.23666996, 20.42092111), (355.28077667, 15.42585916),
#       (356.0867969, 10.49272118), (357.60515292, 5.7288705),
#       (359.79919136, 1.23900864), (2.63747778, -2.87215037),
#       (6.08414126, -6.49930275), (10.08806808, -9.53854284),
#       (14.57261732, -11.89222828), (19.42873515, -13.47647114)],
#      [(5.82340512, 19.4328628), (5.65222123, 16.02038656),
#       (6.05982941, 12.62691485), (7.01297762, 9.34113808),
#       (8.47593598, 6.24739791), (10.40913275, 3.42575699),
#       (12.76663964, 0.95134695), (15.49334789, -1.10715899),
#       (18.52272649, -2.68990855), (21.77603464, -3.74879911)],
#      [(16.24419993, 17.84126158), (16.0593988, 16.11594546),
#       (16.18510227, 14.38584567), (16.61039003, 12.70150121),
#       (17.31766519, 11.11120516), (18.2833084, 9.66005308),
#       (19.47813303, 8.38901655), (20.86777521, 7.33401271),
#       (22.41316309, 6.52497999), (24.07118521, 5.98500671)],
#      [(26.4503327, 15.70893081), (26.4503327, 15.70893081),
#       (26.4503327, 15.70893081), (26.4503327, 15.70893081),
#       (26.4503327, 15.70893081), (26.4503327, 15.70893081),
#       (26.4503327, 15.70893081), (26.4503327, 15.70893081),
#       (26.4503327, 15.70893081), (26.4503327, 15.70893081)]]>
