# %%
import glob
from RadioArray import RadioArray
from ENUFrame import ENU
import numpy as np
import astropy.units as au
import astropy.time as at
import astropy.coordinates as ac
from Geometry import *

def getDatumIdx(antIdx,dirIdx,timeIdx,numDirections,numTimes):
    '''standarizes indexing'''
    idx = antIdx*numDirections*numTimes + dirIdx*numTimes + timeIdx
    return idx

def getDatum(datumIdx,numDirections,numTimes):
    timeIdx = datumIdx % numTimes
    dirIdx = (datumIdx - timeIdx)/numTimes % numDirections
    antIdx = (datumIdx - timeIdx - dirIdx*numTimes)/numDirections/numTimes
    return antIdx,dirIdx,timeIdx    
    
def PrepareData(infoFile,dataFolder,timeStart = 0, timeEnd = 0,arrayFile='arrays/lofar.hba.antenna.cfg',load=False):
    '''Prepare data for continuous inversion. RadioArray, dobs, Cd, and rays.
    Tec is always relative to first antenna[0]
    Output coords are ENU frame'''
    
    print("creating radio array")
    radioArray = RadioArray(arrayFile)
    dataFile = "TecInversionData.npz"
    generate = True
    if load:
        print("Loading:",dataFile)
        try:
            TecData = np.load(dataFile)
            data = TecData['data']
            rays = TecData['rays']
            stationIndices = TecData['stationIndices']
            timeIndices = TecData['timeIndices']
            directionIndices = TecData['directionIndices']
            obstimes = TecData['obstimes']
            numAntennas=TecData['numAntennas']
            numDirections=TecData['numDirections']
            numTimes=TecData['numTimes']
            generate = False
        except:
            print(TecData.keys())
    if generate:
        #things to grab
        outAntennas = {}
        outDirections = {}
        outTimes = {}

        enu = ENU(location=radioArray.getCenter().earth_location)
        print("ENU system set: {0}".format(enu))
        numRays = 0
        #get patch names and directions for dataset
        info = np.load(infoFile)
        patches = info['patches']
        numPatches = len(patches)
        radec = info['directions']
        print("Loaded {0} patches".format(numPatches))
        #get array stations (shoud fold this into radioArray. todo)
        stationLabels = np.genfromtxt(arrayFile, comments='#',usecols = (4),dtype=type(""))
        stationLocs = np.genfromtxt(arrayFile, comments='#',usecols = (0,1,2))
        numStations = len(stationLabels)
        print("Number of stations in array: {0}".format(numStations))
        #assume all times and antennas are same in each datafile
        recievers = []
        numTimes =  (timeEnd - timeStart + 1)
        print("Number of time stamps: {0}".format(numTimes))
        #each time gives a different direction for each patch
        numDirs = numTimes * numPatches #maybe a file doesn't load
        print("Number of possible directions: {0}".format(numDirs))
        data = []
        rays = []
        obstimes = []
        stationIndices = []
        timeIndices = []
        directionIndices = []
        patchIdx = 0
        failed = 0
        while patchIdx < numPatches:
            patch = patches[patchIdx]
            rd = radec[patchIdx]
            #find the appropriate file
            files = glob.glob("{0}/*_{1}_*.npz".format(dataFolder,patch))
            if len(files) == 1:
                file = files[0]
            else:
                print('Could not find patch: {0}'.format(patch))
                patchIdx += 1
                continue
            print("Loading data file: {0}".format(file))
            try:
                d = np.load(file)
            except:
                print("Failed loading data file: {0}".format(file))
                failed += 1
                patchIdx += 1
                continue
            #internal data of each patch file
            antennas = d['antennas']
            times = d['times'][timeStart:timeEnd+1]#gps tai
            tecData = d['data'][timeStart:timeEnd+1,:]#times x antennas
            timeIdx = 0
            while timeIdx < numTimes:

                time = at.Time(times[timeIdx],format='gps',scale='tai')
                print("Processing time: {0}".format(time.isot))

                # get direction of patch at time wrt fixed frame
                dir = ac.SkyCoord(rd.ra,rd.dec,obstime=time,frame='icrs').transform_to(enu)
                
                print("Patch elevation: {0}".format(dir.elevation))
                numRays += 1
                print("Patch east: {0} north: {1} up: {2}".format(dir.east,dir.north,dir.up))
                dir = dir.transform_to('itrs')
                
                antIdx = 0#index in solution table
                while antIdx < len(antennas):
                    ant = antennas[antIdx]
                    #find index in stationLabels
                    labelIdx = 0
                    while labelIdx < numStations:
                        if stationLabels[labelIdx] == ant:
                            break
                        labelIdx += 1
                    if labelIdx >= numStations:
                        print("Could not find {0} in available stations: {1}".format(ant,stationLabels))
                        continue
                    datumIdx = getDatumIdx(antIdx,patchIdx,timeIdx,numPatches,numTimes)
                    #ITRS WGS84
                    stationLoc = ac.SkyCoord(*stationLocs[labelIdx]*au.m,frame='itrs')
                    origin = stationLoc.cartesian.xyz.to(au.km).value#/wavelength enu system
                    rays.append(Ray(origin,dir.cartesian.xyz.value,id = datumIdx,time = time.gps - times[0]))
                    data.append(tecData[timeIdx,antIdx])#-tecData[timeIdx,0])#relative to first antenna?
                    obstimes.append(time.gps - times[0])
                    stationIndices.append(labelIdx)
                    timeIndices.append(timeIdx)
                    directionIndices.append(patchIdx)
                    antIdx += 1
                timeIdx += 1
            patchIdx += 1
        numAntennas=len(antennas)
        numDirections=numPatches
        numTimes=numTimes
        np.savez(dataFile, numAntennas=numAntennas,numDirections=numDirections,numTimes=numTimes,
                 rays=rays,data=data,stationIndices=stationIndices,
                timeIndices=timeIndices,directionIndices=directionIndices,obstimes = obstimes)
    return {'numAntennas':numAntennas,'numDirections':numDirections,'numTimes':numTimes,
            'rays':rays,'dtec':data,'times':obstimes,'radioArray':radioArray}

if __name__ == '__main__':
    dataDict = PrepareData(infoFile='SB120-129/WendysBootes.npz',
                           dataFolder='SB120-129/',
                           timeStart = 1, timeEnd = 50,
                           arrayFile='arrays/lofar.hba.antenna.cfg',load=False)
    rays = dataDict['rays']
    numDirections = dataDict['numDirections']
    numTimes = dataDict['numTimes']
    numAntennas = dataDict['numAntennas']
    data = dataDict['dtec']
    data -= np.min(data)
    data /= np.max(data)
    import pylab as plt
    #f,ax = plt.subplots(int(np.ceil(np.sqrt(numAntennas))),int(np.ceil(np.sqrt(numAntennas))))
    ax = plt.subplot(111)
    print(ax)
    i = 0
    while i < len(rays):
        datumIdx = rays[i].id
        antIdx,dirIdx,timeIdx = getDatum(datumIdx,numDirections,numTimes)
        dir = rays[i].dir
        if antIdx==0:
            print(data[i])
            ax.scatter(dir[0],dir[1],c=data[i],s=(data*50)**2,vmin=0.2,vmax=0.5)
        
        i += 1
    plt.show()
# Out:
# creating radio array
# ENU system set: <ENU Frame (obstime=None, location=(3826815.6193548394, 459218.61553225806, 5064855.010467743) m)>
# Loaded 34 patches
# Number of stations in array: 62
# Number of time stamps: 50
# Number of possible directions: 1700
# Loading data file: SB120-129\BOOTES24_SB120-129.2ch8s.ms_instrument_master_s1_norm.npz
# Processing time: 2014-08-10T13:00:08.013
# Patch elevation: 0.791325110503 rad
# Patch east: 0.70259262666 north: 0.0208995851825 up: 0.711285321304
# Processing time: 2014-08-10T13:00:16.027
# Patch elevation: 0.791677316925 rad
# Patch east: 0.702351620781 north: 0.0205721244881 up: 0.711532844274
# Processing time: 2014-08-10T13:00:24.040
# Patch elevation: 0.792029527995 rad
# Patch east: 0.702110375116 north: 0.0202447762437 up: 0.711780282243
# Processing time: 2014-08-10T13:00:32.053
# Patch elevation: 0.792381743694 rad
# Patch east: 0.701868889709 north: 0.0199175405125 up: 0.712027635164
# Processing time: 2014-08-10T13:00:40.067
# Patch elevation: 0.792733963983 rad
# Patch east: 0.701627164624 north: 0.0195904173769 up: 0.712274902976
# Processing time: 2014-08-10T13:00:48.080
# Patch elevation: 0.793086188725 rad
# Patch east: 0.701385199984 north: 0.019263407007 up: 0.712522085548
# Processing time: 2014-08-10T13:00:56.093
# Patch elevation: 0.793438417882 rad
# Patch east: 0.701142995851 north: 0.0189365094854 up: 0.712769182819
# Processing time: 2014-08-10T13:01:04.107
# Patch elevation: 0.79379065138 rad
# Patch east: 0.700900552309 north: 0.0186097249236 up: 0.713016194705
# Processing time: 2014-08-10T13:01:12.120
# Patch elevation: 0.794142889202 rad
# Patch east: 0.700657869402 north: 0.0182830533846 up: 0.713263121158
# Processing time: 2014-08-10T13:01:20.133
# Patch elevation: 0.794495131168 rad
# Patch east: 0.700414947288 north: 0.0179564950772 up: 0.713509962019
# Processing time: 2014-08-10T13:01:28.147
# Patch elevation: 0.794847377261 rad
# Patch east: 0.700171786011 north: 0.0176300500643 up: 0.713756717242
# Processing time: 2014-08-10T13:01:36.160
# Patch elevation: 0.79519962744 rad
# Patch east: 0.699928385635 north: 0.0173037184281 up: 0.714003386765
# Processing time: 2014-08-10T13:01:44.174
# Patch elevation: 0.795551881568 rad
# Patch east: 0.699684746284 north: 0.0169775003385 up: 0.714249970458
# Processing time: 2014-08-10T13:01:52.187
# Patch elevation: 0.795904139606 rad
# Patch east: 0.699440868021 north: 0.0166513958776 up: 0.71449646826
# Processing time: 2014-08-10T13:02:00.200
# Patch elevation: 0.796256401533 rad
# Patch east: 0.699196750893 north: 0.0163254051083 up: 0.714742880124
# Processing time: 2014-08-10T13:02:08.214
# Patch elevation: 0.796608667172 rad
# Patch east: 0.698952395056 north: 0.0159995282389 up: 0.714989205892
# Processing time: 2014-08-10T13:02:16.227
# Patch elevation: 0.796960936513 rad
# Patch east: 0.698707800549 north: 0.0156737653225 up: 0.715235445523
# Processing time: 2014-08-10T13:02:24.240
# Patch elevation: 0.797313209463 rad
# Patch east: 0.698462967471 north: 0.0153481164897 up: 0.715481598919
# Processing time: 2014-08-10T13:02:32.254
# Patch elevation: 0.797665485981 rad
# Patch east: 0.698217895883 north: 0.0150225818227 up: 0.715727666018
# Processing time: 2014-08-10T13:02:40.267
# Patch elevation: 0.798017765952 rad
# Patch east: 0.697972585898 north: 0.0146971614713 up: 0.715973646707
# Processing time: 2014-08-10T13:02:48.280
# Patch elevation: 0.798370049323 rad
# Patch east: 0.697727037586 north: 0.0143718555273 up: 0.716219540916
# Processing time: 2014-08-10T13:02:56.294
# Patch elevation: 0.798722336086 rad
# Patch east: 0.697481250986 north: 0.0140466640437 up: 0.716465348606
# Processing time: 2014-08-10T13:03:04.307
# Patch elevation: 0.799074626041 rad
# Patch east: 0.69723522627 north: 0.0137215872477 up: 0.716711069603
# Processing time: 2014-08-10T13:03:12.320
# Patch elevation: 0.799426919177 rad
# Patch east: 0.696988963478 north: 0.0133966251921 up: 0.71695670387
# Processing time: 2014-08-10T13:03:20.334
# Patch elevation: 0.799779215444 rad
# Patch east: 0.696742462679 north: 0.0130717779687 up: 0.717202251335
# Processing time: 2014-08-10T13:03:28.347
# Patch elevation: 0.800131514725 rad
# Patch east: 0.696495723988 north: 0.0127470457271 up: 0.717447711887
# Processing time: 2014-08-10T13:03:36.360
# Patch elevation: 0.800483816969 rad
# Patch east: 0.696248747473 north: 0.0124224285586 up: 0.717693085456
# Processing time: 2014-08-10T13:03:44.374
# Patch elevation: 0.800836122101 rad
# Patch east: 0.69600153322 north: 0.0120979265743 up: 0.717938371957
# Processing time: 2014-08-10T13:03:52.387
# Patch elevation: 0.801188430112 rad
# Patch east: 0.695754081267 north: 0.011773539827 up: 0.718183571352
# Processing time: 2014-08-10T13:04:00.400
# Patch elevation: 0.801540740801 rad
# Patch east: 0.695506391788 north: 0.0114492685433 up: 0.718428683469
# Processing time: 2014-08-10T13:04:08.414
# Patch elevation: 0.801893054159 rad
# Patch east: 0.695258464824 north: 0.011125112776 up: 0.718673708268
# Processing time: 2014-08-10T13:04:16.427
# Patch elevation: 0.802245370133 rad
# Patch east: 0.695010300445 north: 0.0108010726165 up: 0.71891864568
# Processing time: 2014-08-10T13:04:24.441
# Patch elevation: 0.802597688606 rad
# Patch east: 0.694761898764 north: 0.010477148214 up: 0.719163495592
# Processing time: 2014-08-10T13:04:32.454
# Patch elevation: 0.802950009527 rad
# Patch east: 0.694513259851 north: 0.0101533396598 up: 0.719408257935
# Processing time: 2014-08-10T13:04:40.467
# Patch elevation: 0.803302332883 rad
# Patch east: 0.694264383748 north: 0.00982964700679 up: 0.719652932669
# Processing time: 2014-08-10T13:04:48.481
# Patch elevation: 0.803654658475 rad
# Patch east: 0.694015270627 north: 0.00950607048098 up: 0.719897519623
# Processing time: 2014-08-10T13:04:56.494
# Patch elevation: 0.804006986293 rad
# Patch east: 0.693765920531 north: 0.00918261013509 up: 0.720142018758
# Processing time: 2014-08-10T13:05:04.507
# Patch elevation: 0.804359316282 rad
# Patch east: 0.693516333528 north: 0.00885926606031 up: 0.720386430005
# Processing time: 2014-08-10T13:05:12.521
# Patch elevation: 0.804711648327 rad
# Patch east: 0.693266509734 north: 0.00853603840555 up: 0.72063075325
# Processing time: 2014-08-10T13:05:20.534
# Patch elevation: 0.805063982374 rad
# Patch east: 0.693016449219 north: 0.00821292726194 up: 0.720874988426
# Processing time: 2014-08-10T13:05:28.547
# Patch elevation: 0.805416318348 rad
# Patch east: 0.692766152069 north: 0.00788993273979 up: 0.721119135448
# Processing time: 2014-08-10T13:05:36.561
# Patch elevation: 0.805768656239 rad
# Patch east: 0.692515618324 north: 0.00756705489177 up: 0.721363194277
# Processing time: 2014-08-10T13:05:44.574
# Patch elevation: 0.806120995846 rad
# Patch east: 0.69226484816 north: 0.0072442939434 up: 0.721607164742
# Processing time: 2014-08-10T13:05:52.587
# Patch elevation: 0.806473337157 rad
# Patch east: 0.692013841617 north: 0.00692164994724 up: 0.721851046804
# Processing time: 2014-08-10T13:06:00.601
# Patch elevation: 0.806825680118 rad
# Patch east: 0.691762598766 north: 0.00659912299427 up: 0.722094840394
# Processing time: 2014-08-10T13:06:08.614
# Patch elevation: 0.807178024612 rad
# Patch east: 0.691511119723 north: 0.00627671323302 up: 0.7223385454
# Processing time: 2014-08-10T13:06:16.627
# Patch elevation: 0.807530370587 rad
# Patch east: 0.691259404558 north: 0.00595442075436 up: 0.722582161753
# Processing time: 2014-08-10T13:06:24.641
# Patch elevation: 0.807882718028 rad
# Patch east: 0.691007453313 north: 0.00563224561085 up: 0.722825689413
# Processing time: 2014-08-10T13:06:32.654
# Patch elevation: 0.808235066737 rad
# Patch east: 0.690755266164 north: 0.00531018802753 up: 0.72306912821
# Processing time: 2014-08-10T13:06:40.667
# Patch elevation: 0.8085874167 rad
# Patch east: 0.690502843151 north: 0.00498824805682 up: 0.723312478104
# Loading data file: SB120-129\BOOTES24_SB120-129.2ch8s.ms_instrument_master_s2_norm.npz
# Processing time: 2014-08-10T13:00:08.013
# Patch elevation: 0.779592737278 rad
# Patch east: 0.711182365951 north: -0.00499380016272 up: 0.702989832302
# Processing time: 2014-08-10T13:00:16.027
# Patch elevation: 0.779945087792 rad
# Patch east: 0.710932211311 north: -0.00532526285103 up: 0.703240380308
# Processing time: 2014-08-10T13:00:24.040
# Patch elevation: 0.780297437016 rad
# Patch east: 0.710681813955 north: -0.00565660882328 up: 0.70349084009
# Processing time: 2014-08-10T13:00:32.053
# Patch elevation: 0.780649784925 rad
# Patch east: 0.710431173932 north: -0.00598783801564 up: 0.703741211598
# Processing time: 2014-08-10T13:00:40.067
# Patch elevation: 0.781002131471 rad
# Patch east: 0.710180291305 north: -0.00631895034456 up: 0.70399149477
# Processing time: 2014-08-10T13:00:48.080
# Patch elevation: 0.781354476514 rad
# Patch east: 0.709929166204 north: -0.00664994563788 up: 0.704241689476
# Processing time: 2014-08-10T13:00:56.093
# Patch elevation: 0.781706820008 rad
# Patch east: 0.709677798692 north: -0.00698082381214 up: 0.704491795653
# Processing time: 2014-08-10T13:01:04.107
# Patch elevation: 0.782059161873 rad
# Patch east: 0.709426188857 north: -0.00731158475433 up: 0.704741813214
# Processing time: 2014-08-10T13:01:12.120
# Patch elevation: 0.782411502084 rad
# Patch east: 0.709174336745 north: -0.00764222840073 up: 0.704991742113
# Processing time: 2014-08-10T13:01:20.133
# Patch elevation: 0.782763840458 rad
# Patch east: 0.708922242518 north: -0.00797275454004 up: 0.705241582189
# Processing time: 2014-08-10T13:01:28.147
# Patch elevation: 0.783116176969 rad
# Patch east: 0.708669906225 north: -0.00830316310861 up: 0.705491333394
# Processing time: 2014-08-10T13:01:36.160
# Patch elevation: 0.783468511569 rad
# Patch east: 0.708417327929 north: -0.00863345402308 up: 0.705740995665
# Processing time: 2014-08-10T13:01:44.174
# Patch elevation: 0.783820844118 rad
# Patch east: 0.708164507761 north: -0.00896362711171 up: 0.705990568872
# Processing time: 2014-08-10T13:01:52.187
# Patch elevation: 0.784173174567 rad
# Patch east: 0.707911445786 north: -0.00929368229126 up: 0.706240052953
# Processing time: 2014-08-10T13:02:00.200
# Patch elevation: 0.78452550289 rad
# Patch east: 0.707658142051 north: -0.0096236194981 up: 0.706489447859
# Processing time: 2014-08-10T13:02:08.214
# Patch elevation: 0.784877828905 rad
# Patch east: 0.70740459672 north: -0.0099534385214 up: 0.706738753431
# Processing time: 2014-08-10T13:02:16.227
# Patch elevation: 0.785230152593 rad
# Patch east: 0.707150809833 north: -0.0102831393074 up: 0.706987969628
# Processing time: 2014-08-10T13:02:24.240
# Patch elevation: 0.785582473856 rad
# Patch east: 0.706896781491 north: -0.010612721724 up: 0.707237096351
# Processing time: 2014-08-10T13:02:32.254
# Patch elevation: 0.785934792646 rad
# Patch east: 0.70664251176 north: -0.010942185688 up: 0.707486133536
# Processing time: 2014-08-10T13:02:40.267
# Patch elevation: 0.786287108842 rad
# Patch east: 0.706388000756 north: -0.0112715310477 up: 0.707735081069
# Processing time: 2014-08-10T13:02:48.280
# Patch elevation: 0.786639422385 rad
# Patch east: 0.70613324855 north: -0.0116007577103 up: 0.70798393888
# Processing time: 2014-08-10T13:02:56.294
# Patch elevation: 0.786991733258 rad
# Patch east: 0.705878255185 north: -0.0119298656221 up: 0.708232706928
# Processing time: 2014-08-10T13:03:04.307
# Patch elevation: 0.787344041257 rad
# Patch east: 0.705623020839 north: -0.0122588545531 up: 0.708481385039
# Processing time: 2014-08-10T13:03:12.320
# Patch elevation: 0.787696346364 rad
# Patch east: 0.705367545552 north: -0.01258772445 up: 0.708729973174
# Processing time: 2014-08-10T13:03:20.334
# Patch elevation: 0.788048648522 rad
# Patch east: 0.705111829398 north: -0.0129164752198 up: 0.708978471261
# Processing time: 2014-08-10T13:03:28.347
# Patch elevation: 0.788400947607 rad
# Patch east: 0.704855872493 north: -0.0132451067112 up: 0.709226879186
# Processing time: 2014-08-10T13:03:36.360
# Patch elevation: 0.788753243562 rad
# Patch east: 0.704599674911 north: -0.0135736188316 up: 0.70947519688
# Processing time: 2014-08-10T13:03:44.374
# Patch elevation: 0.789105536307 rad
# Patch east: 0.704343236738 north: -0.0139020114688 up: 0.709723424257
# Processing time: 2014-08-10T13:03:52.387
# Patch elevation: 0.789457825824 rad
# Patch east: 0.704086558016 north: -0.0142302845692 up: 0.709971561277
# Processing time: 2014-08-10T13:04:00.400
# Patch elevation: 0.789810111907 rad
# Patch east: 0.703829638925 north: -0.0145584379037 up: 0.710219607767
# Processing time: 2014-08-10T13:04:08.414
# Patch elevation: 0.790162394539 rad
# Patch east: 0.703572479506 north: -0.0148864714186 up: 0.710467563686
# Processing time: 2014-08-10T13:04:16.427
# Patch elevation: 0.790514673662 rad
# Patch east: 0.703315079832 north: -0.0152143850216 up: 0.710715428965
# Processing time: 2014-08-10T13:04:24.441
# Patch elevation: 0.790866949151 rad
# Patch east: 0.703057440022 north: -0.0155421785616 up: 0.710963203489
# Processing time: 2014-08-10T13:04:32.454
# Patch elevation: 0.791219220949 rad
# Patch east: 0.702799560148 north: -0.0158698519462 up: 0.711210887189
# Processing time: 2014-08-10T13:04:40.467
# Patch elevation: 0.791571489036 rad
# Patch east: 0.702541440251 north: -0.0161974051221 up: 0.711458480023
# Processing time: 2014-08-10T13:04:48.481
# Patch elevation: 0.791923753208 rad
# Patch east: 0.702283080514 north: -0.0165248378603 up: 0.71170598182
# Processing time: 2014-08-10T13:04:56.494
# Patch elevation: 0.792276013446 rad
# Patch east: 0.702024480976 north: -0.0168521501076 up: 0.711953392538
# Processing time: 2014-08-10T13:05:04.507
# Patch elevation: 0.79262826969 rad
# Patch east: 0.701765641712 north: -0.0171793417718 up: 0.712200712109
# Processing time: 2014-08-10T13:05:12.521
# Patch elevation: 0.792980521817 rad
# Patch east: 0.701506562841 north: -0.017506412702 up: 0.712447940417
# Processing time: 2014-08-10T13:05:20.534
# Patch elevation: 0.793332769767 rad
# Patch east: 0.701247244436 north: -0.0178333628062 up: 0.712695077395
# Processing time: 2014-08-10T13:05:28.547
# Patch elevation: 0.793685013459 rad
# Patch east: 0.700987686584 north: -0.0181601919726 up: 0.712942122956
# Processing time: 2014-08-10T13:05:36.561
# Patch elevation: 0.794037252876 rad
# Patch east: 0.700727889329 north: -0.0184869001481 up: 0.713189077061
# Processing time: 2014-08-10T13:05:44.574
# Patch elevation: 0.794389487809 rad
# Patch east: 0.700467852852 north: -0.0188134871043 up: 0.713435939537
# Processing time: 2014-08-10T13:05:52.587
# Patch elevation: 0.79474171824 rad
# Patch east: 0.700207577196 north: -0.0191399527882 up: 0.713682710345
# Processing time: 2014-08-10T13:06:00.601
# Patch elevation: 0.79509394411 rad
# Patch east: 0.699947062433 north: -0.0194662971076 up: 0.713929389414
# Processing time: 2014-08-10T13:06:08.614
# Patch elevation: 0.795446165293 rad
# Patch east: 0.699686308684 north: -0.0197925199123 up: 0.714175976631
# Processing time: 2014-08-10T13:06:16.627
# Patch elevation: 0.795798381731 rad
# Patch east: 0.699425316021 north: -0.0201186211103 up: 0.714422471926
# Processing time: 2014-08-10T13:06:24.641
# Patch elevation: 0.796150593403 rad
# Patch east: 0.699164084489 north: -0.0204446006485 up: 0.71466887526
# Processing time: 2014-08-10T13:06:32.654
# Patch elevation: 0.796502800102 rad
# Patch east: 0.698902614269 north: -0.0207704582991 up: 0.714915186459
# Processing time: 2014-08-10T13:06:40.667
# Patch elevation: 0.79685500181 rad
# Patch east: 0.698640905404 north: -0.0210961940091 up: 0.715161405485
# Loading data file: SB120-129\BOOTES24_SB120-129.2ch8s.ms_instrument_master_s251_norm.npz
# Processing time: 2014-08-10T13:00:08.013
# Patch elevation: 0.838518087344 rad
# Patch east: 0.668244369497 north: -0.0207221838089 up: 0.743653181082
# Processing time: 2014-08-10T13:00:16.027
# Patch elevation: 0.838870275186 rad
# Patch east: 0.66797256222 north: -0.0210336257995 up: 0.743888595629
# Processing time: 2014-08-10T13:00:24.040
# Patch elevation: 0.839222457668 rad
# Patch east: 0.6677005269 north: -0.021344940987 up: 0.744123914326
# Processing time: 2014-08-10T13:00:32.053
# Patch elevation: 0.839574634761 rad
# Patch east: 0.667428263588 north: -0.0216561293114 up: 0.744359137128
# Processing time: 2014-08-10T13:00:40.067
# Patch elevation: 0.839926806411 rad
# Patch east: 0.667155772354 north: -0.0219671906942 up: 0.744594263977
# Processing time: 2014-08-10T13:00:48.080
# Patch elevation: 0.840278972475 rad
# Patch east: 0.66688305334 north: -0.0222781249736 up: 0.744829294749
# Processing time: 2014-08-10T13:00:56.093
# Patch elevation: 0.840631132899 rad
# Patch east: 0.666610106613 north: -0.0225889320714 up: 0.745064229385
# Processing time: 2014-08-10T13:01:04.107
# Patch elevation: 0.840983287601 rad
# Patch east: 0.666336932268 north: -0.0228996118812 up: 0.745299067805
# Processing time: 2014-08-10T13:01:12.120
# Patch elevation: 0.84133543655 rad
# Patch east: 0.666063530356 north: -0.0232101643433 up: 0.745533809965
# Processing time: 2014-08-10T13:01:20.133
# Patch elevation: 0.841687579557 rad
# Patch east: 0.665789901053 north: -0.0235205892593 up: 0.745768455713
# Processing time: 2014-08-10T13:01:28.147
# Patch elevation: 0.842039716591 rad
# Patch east: 0.665516044412 north: -0.0238308865692 up: 0.746003005004
# Processing time: 2014-08-10T13:01:36.160
# Patch elevation: 0.842391847601 rad
# Patch east: 0.665241960501 north: -0.0241410561949 up: 0.746237457781
# Processing time: 2014-08-10T13:01:44.174
# Patch elevation: 0.842743972438 rad
# Patch east: 0.664967649462 north: -0.024451097975 up: 0.746471813919
# Processing time: 2014-08-10T13:01:52.187
# Patch elevation: 0.843096091051 rad
# Patch east: 0.664693111366 north: -0.0247610118314 up: 0.746706073362
# Processing time: 2014-08-10T13:02:00.200
# Patch elevation: 0.843448203408 rad
# Patch east: 0.664418346265 north: -0.0250707977044 up: 0.746940236062
# Processing time: 2014-08-10T13:02:08.214
# Patch elevation: 0.843800309321 rad
# Patch east: 0.664143354334 north: -0.025380455396 up: 0.747174301872
# Processing time: 2014-08-10T13:02:16.227
# Patch elevation: 0.844152408768 rad
# Patch east: 0.663868135619 north: -0.0256899848557 up: 0.747408270751
# Processing time: 2014-08-10T13:02:24.240
# Patch elevation: 0.844504501643 rad
# Patch east: 0.66359269023 north: -0.0259993859595 up: 0.747642142608
# Processing time: 2014-08-10T13:02:32.254
# Patch elevation: 0.844856587894 rad
# Patch east: 0.663317018235 north: -0.0263086586293 up: 0.747875917382
# Processing time: 2014-08-10T13:02:40.267
# Patch elevation: 0.845208667394 rad
# Patch east: 0.663041119763 north: -0.0266178027227 up: 0.748109594967
# Processing time: 2014-08-10T13:02:48.280
# Patch elevation: 0.84556074008 rad
# Patch east: 0.662764994891 north: -0.0269268181526 up: 0.748343175296
# Processing time: 2014-08-10T13:02:56.294
# Patch elevation: 0.845912805929 rad
# Patch east: 0.662488643663 north: -0.0272357048685 up: 0.748576658331
# Processing time: 2014-08-10T13:03:04.307
# Patch elevation: 0.846264864732 rad
# Patch east: 0.662212066274 north: -0.0275444626547 up: 0.748810043909
# Processing time: 2014-08-10T13:03:12.320
# Patch elevation: 0.846616916465 rad
# Patch east: 0.661935262767 north: -0.027853091461 up: 0.749043331992
# Processing time: 2014-08-10T13:03:20.334
# Patch elevation: 0.846968961066 rad
# Patch east: 0.661658233222 north: -0.0281615912003 up: 0.749276522514
# Processing time: 2014-08-10T13:03:28.347
# Patch elevation: 0.847320998406 rad
# Patch east: 0.661380977765 north: -0.0284699617306 up: 0.749509615368
# Processing time: 2014-08-10T13:03:36.360
# Patch elevation: 0.847673028421 rad
# Patch east: 0.661103496475 north: -0.0287782029648 up: 0.749742610489
# Processing time: 2014-08-10T13:03:44.374
# Patch elevation: 0.848025051027 rad
# Patch east: 0.660825789446 north: -0.0290863147979 up: 0.749975507796
# Processing time: 2014-08-10T13:03:52.387
# Patch elevation: 0.8483770662 rad
# Patch east: 0.660547856725 north: -0.0293942971795 up: 0.750208307252
# Processing time: 2014-08-10T13:04:00.400
# Patch elevation: 0.84872907373 rad
# Patch east: 0.660269698504 north: -0.0297021498944 up: 0.750441008694
# Processing time: 2014-08-10T13:04:08.414
# Patch elevation: 0.849081073592 rad
# Patch east: 0.659991314829 north: -0.0300098728927 up: 0.750673612084
# Processing time: 2014-08-10T13:04:16.427
# Patch elevation: 0.849433065723 rad
# Patch east: 0.659712705779 north: -0.0303174660875 up: 0.750906117357
# Processing time: 2014-08-10T13:04:24.441
# Patch elevation: 0.849785049995 rad
# Patch east: 0.659433871482 north: -0.0306249293372 up: 0.751138524405
# Processing time: 2014-08-10T13:04:32.454
# Patch elevation: 0.850137026342 rad
# Patch east: 0.659154812017 north: -0.030932262555 up: 0.751370833163
# Processing time: 2014-08-10T13:04:40.467
# Patch elevation: 0.850488994741 rad
# Patch east: 0.658875527429 north: -0.0312394656909 up: 0.751603043593
# Processing time: 2014-08-10T13:04:48.481
# Patch elevation: 0.85084095498 rad
# Patch east: 0.658596017913 north: -0.0315465385304 up: 0.751835155534
# Processing time: 2014-08-10T13:04:56.494
# Patch elevation: 0.851192907036 rad
# Patch east: 0.658316283514 north: -0.0318534810233 up: 0.752067168946
# Processing time: 2014-08-10T13:05:04.507
# Patch elevation: 0.851544850844 rad
# Patch east: 0.658036324313 north: -0.0321602930832 up: 0.752299083765
# Processing time: 2014-08-10T13:05:12.521
# Patch elevation: 0.851896786273 rad
# Patch east: 0.657756140436 north: -0.0324669745688 up: 0.752530899884
# Processing time: 2014-08-10T13:05:20.534
# Patch elevation: 0.85224871326 rad
# Patch east: 0.657475731965 north: -0.0327735253936 up: 0.752762617238
# Processing time: 2014-08-10T13:05:28.547
# Patch elevation: 0.852600631717 rad
# Patch east: 0.657195098993 north: -0.0330799454529 up: 0.752994235747
# Processing time: 2014-08-10T13:05:36.561
# Patch elevation: 0.852952541619 rad
# Patch east: 0.656914241568 north: -0.0333862346968 up: 0.753225755374
# Processing time: 2014-08-10T13:05:44.574
# Patch elevation: 0.853304442755 rad
# Patch east: 0.656633159885 north: -0.0336923929114 up: 0.753457175956
# Processing time: 2014-08-10T13:05:52.587
# Patch elevation: 0.8536563351 rad
# Patch east: 0.656351853989 north: -0.0339984200467 up: 0.753688497457
# Processing time: 2014-08-10T13:06:00.601
# Patch elevation: 0.854008218587 rad
# Patch east: 0.656070323961 north: -0.0343043160166 up: 0.753919719811
# Processing time: 2014-08-10T13:06:08.614
# Patch elevation: 0.854360093088 rad
# Patch east: 0.65578856993 north: -0.03461008068 up: 0.754150842912
# Processing time: 2014-08-10T13:06:16.627
# Patch elevation: 0.854711958535 rad
# Patch east: 0.655506591975 north: -0.0349157139509 up: 0.754381866694
# Processing time: 2014-08-10T13:06:24.641
# Patch elevation: 0.855063814905 rad
# Patch east: 0.655224390142 north: -0.0352212157795 up: 0.75461279112
# Processing time: 2014-08-10T13:06:32.654
# Patch elevation: 0.855415661982 rad
# Patch east: 0.654941964629 north: -0.0355265859522 up: 0.754843616028
# Processing time: 2014-08-10T13:06:40.667
# Patch elevation: 0.855767499744 rad
# Patch east: 0.654659315482 north: -0.0358318244194 up: 0.755074341381
# Loading data file: SB120-129\BOOTES24_SB120-129.2ch8s.ms_instrument_master_s252_norm.npz
# Processing time: 2014-08-10T13:00:08.013
# Patch elevation: 0.833341596398 rad
# Patch east: 0.671685490766 north: -0.0311223773745 up: 0.740182409356
# Processing time: 2014-08-10T13:00:16.027
# Patch elevation: 0.833693574546 rad
# Patch east: 0.671410057776 north: -0.0314354226062 up: 0.740419035765
# Processing time: 2014-08-10T13:00:24.040
# Patch elevation: 0.83404554466 rad
# Patch east: 0.671134395568 north: -0.0317483393441 up: 0.740655565046
# Processing time: 2014-08-10T13:00:32.053
# Patch elevation: 0.834397506707 rad
# Patch east: 0.670858504197 north: -0.0320611275279 up: 0.740891997155
# Processing time: 2014-08-10T13:00:40.067
# Patch elevation: 0.834749460631 rad
# Patch east: 0.670582383732 north: -0.0323737870788 up: 0.74112833203
# Processing time: 2014-08-10T13:00:48.080
# Patch elevation: 0.835101406284 rad
# Patch east: 0.670306034317 north: -0.0326863178342 up: 0.741364569551
# Processing time: 2014-08-10T13:00:56.093
# Patch elevation: 0.835453343611 rad
# Patch east: 0.670029456021 north: -0.0329987197152 up: 0.741600709656
# Processing time: 2014-08-10T13:01:04.107
# Patch elevation: 0.835805272526 rad
# Patch east: 0.669752648938 north: -0.0333109926152 up: 0.741836752265
# Processing time: 2014-08-10T13:01:12.120
# Patch elevation: 0.836157192995 rad
# Patch east: 0.669475613123 north: -0.0336231364741 up: 0.742072697333
# Processing time: 2014-08-10T13:01:20.133
# Patch elevation: 0.836509104826 rad
# Patch east: 0.669198348751 north: -0.0339351510922 up: 0.74230854471
# Processing time: 2014-08-10T13:01:28.147
# Patch elevation: 0.836861007984 rad
# Patch east: 0.668920855877 north: -0.0342470364097 up: 0.742544294348
# Processing time: 2014-08-10T13:01:36.160
# Patch elevation: 0.837212902416 rad
# Patch east: 0.668643134571 north: -0.0345587923477 up: 0.74277994619
# Processing time: 2014-08-10T13:01:44.174
# Patch elevation: 0.83756478797 rad
# Patch east: 0.668365184977 north: -0.0348704187441 up: 0.743015500113
# Processing time: 2014-08-10T13:01:52.187
# Patch elevation: 0.837916664592 rad
# Patch east: 0.668087007164 north: -0.0351819155205 up: 0.743250956056
# Processing time: 2014-08-10T13:02:00.200
# Patch elevation: 0.838268532246 rad
# Patch east: 0.667808601187 north: -0.0354932826167 up: 0.743486313976
# Processing time: 2014-08-10T13:02:08.214
# Patch elevation: 0.838620390741 rad
# Patch east: 0.667529967224 north: -0.0358045198338 up: 0.743721573721
